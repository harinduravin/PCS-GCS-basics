# %%
import numpy as np
import tensorflow as tf
import importlib
import end_to_end_model
importlib.reload(end_to_end_model)
import sionna as sn
from sionna.phy.mapping import Constellation
from end_to_end_model import EndToEndSystem_bitwise_P0_fixed, normalize_constellation, plot_constellation_wlabels
# Out:
# 2025-10-18 23:55:10.418525: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/harindu/anaconda3/envs/myenvtf/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
gpu_available = tf.test.is_gpu_available()
is_cuda_gpu_available = tf.test.is_gpu_available(cuda_only=True)
is_cuda_gpu_min_3 = tf.test.is_gpu_available(True, (3,0))

print(is_cuda_gpu_available)
print(is_cuda_gpu_min_3)
print(gpu_available)

ebno_db = tf.random.uniform(shape=[100], minval=5.0, maxval=5.2)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_9619/4250530009.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# True
# True
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760820911.967534    9619 gpu_device.cc:2020] Created device /device:GPU:0 with 6112 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1760820911.968669    9619 gpu_device.cc:2020] Created device /device:GPU:0 with 6112 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6
# I0000 00:00:1760820911.969088    9619 gpu_device.cc:2020] Created device /device:GPU:0 with 6112 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6
# ...

# %%
# APSK 32
constellation = np.array([0.192425859850790 + 0.192425859850790j,
0.693946738059284 + 0.185942468053197j,
0.192425859850790 - 0.192425859850790j,
0.693946738059283 - 0.185942468053197j,
-0.192425859850790 + 0.192425859850790j,
-0.693946738059284 + 0.185942468053197j,
-0.192425859850790 - 0.192425859850790j,
-0.693946738059284 - 0.185942468053197j,
0.185942468053197 + 0.693946738059283j,
0.508004270006087 + 0.508004270006087j,
0.185942468053197 - 0.693946738059284j,
0.508004270006087 - 0.508004270006087j,
-0.185942468053197 + 0.693946738059284j,
-0.508004270006087 + 0.508004270006087j,
-0.185942468053197 - 0.693946738059283j,
-0.508004270006087 - 0.508004270006087j,
0.892855989707667 + 0.892855989707667j,
1.26268904989064 + 0.00000000000000j,
0.483210179621963 - 1.16657256912008j,
1.16657256912008 - 0.483210179621963j,
-0.483210179621963 + 1.16657256912008j,
-1.16657256912008 + 0.483210179621963j,
-0.892855989707668 - 0.892855989707667j,
-1.26268904989064 + 1.54634810326698e-16j,
0.483210179621963 + 1.16657256912008j,
1.16657256912008 + 0.483210179621963j,
-2.31952215490047e-16 - 1.26268904989064j,
0.892855989707667 - 0.892855989707668j,
7.73174051633490e-17 + 1.26268904989064j,
-0.892855989707667 + 0.892855989707667j,
-0.483210179621963 - 1.16657256912008j,
-1.16657256912008 - 0.483210179621962j])

# constellation = np.array([-0.6772403 +0.10144884j,  0.4967456 -0.5206791j ,
#        -0.2647535 -0.11175008j,  0.12471528-0.31633902j,
#        -0.7811502 -0.31070608j,  0.8312866 +0.39706144j,
#        -0.39734668-0.42828754j, -0.06173835-0.58735466j,
#        -0.4754198 +0.4486131j ,  0.6755086 -0.14745077j,
#        -0.14660223+0.12835j   ,  0.2689276 -0.0392331j ,
#        -0.08922593+0.685956j  ,  0.40293464+0.6400089j ,
#         0.00559692+0.34135044j,  0.31354228+0.26335475j,
#         1.0670493 -0.69460726j, -1.1458404 +0.49778244j,
#        -1.334897  -0.0460288j ,  0.21696685-0.9607745j ,
#        -0.06628854+1.2539856j ,  0.35964933+1.212515j  ,
#        -0.5238117 -0.79258037j, -0.16540048-0.9052683j ,
#        -0.722836  +0.8333362j ,  1.1762638 -0.1403979j ,
#         0.70015633-1.1557006j ,  0.2129595 -1.2556154j ,
#        -0.3943663 +1.0253876j ,  0.7634951 +0.97863144j,
#        -0.8364888 -0.9644203j , -0.29826748-1.238291j  ])

# constellation = Constellation("custom", num_bits_per_symbol=5,points=constellation)
# constellation.show(labels=True, figsize=(5, 5))

# %%
import sionna as sn
N = 32  # Number of classes (symbols)
# tf.compat.v1.enable_eager_execution()
# Generate phase angles equally spaced between 0 and 2pi
# angles = np.linspace(0, 2 * np.pi, int(N/2), endpoint=False)
# constellation1 = np.random.permutation(0.5*np.exp(1j * angles))
# constellation2 = np.random.permutation(1.2*np.exp(1j * angles))
# # Convert the angles to complex symbols on the unit circle
# constellation = np.concatenate((constellation1, constellation2), axis=0)

# snr_db = 12  # SNR in dB
# No = 1/(10**(snr_db/10))
tau = 10

# Batch size
batch_size = 1000

ebno_db = tf.random.uniform(shape=[batch_size], minval=5.0, maxval=5.0)

No = sn.phy.utils.ebnodb2no(ebno_db, num_bits_per_symbol=5, coderate=3/5)
No = tf.expand_dims(No, axis=-1)

# print(No.shape)

device = "/GPU:0" if tf.config.list_physical_devices('GPU') else "/CPU:0"

# tf_const_points = tf.reshape(tf.cast(constellation, dtype=tf.complex64), (1, 1, 32))
# print(tf_const_points)

constellation_orig = Constellation("pam", num_bits_per_symbol=5)
# Instantiating the end-to-end model for training
model = EndToEndSystem_bitwise_P0_fixed(N, constellation, device, constellation_orig, tau)

loss, loss_ordinary, entropy_value,shaping_probs, norm_C_points = model(ebno_db, No)
print(loss_ordinary)
# print(shaping_probs)
# print(norm_C_points)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760819974.717756    7519 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5930 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
N = 32  # Number of classes (symbols)

# Generate phase angles equally spaced between 0 and 2pi
# angles = np.linspace(0, 2 * np.pi, int(N/2), endpoint=False)
# constellation1 = np.random.permutation(0.5*np.exp(1j * angles))
# constellation2 = np.random.permutation(1.2*np.exp(1j * angles))
# # Convert the angles to complex symbols on the unit circle
# constellation = np.concatenate((constellation1, constellation2), axis=0)

# Generate phase angles equally spaced between 0 and 2pi
# angles = np.linspace(0, 2 * np.pi, int(N), endpoint=False)
# constellation = np.random.permutation(np.exp(1j * angles))
constellation_orig = Constellation("pam", num_bits_per_symbol=5)

# snr_db = 10  # SNR in dB
# No = 1/(10**(snr_db/10))

tau = 10

# Batch size
batch_size = 10

ebno_db = tf.random.uniform(shape=[batch_size], minval=5.0, maxval=5.2)
No = sn.phy.utils.ebnodb2no(ebno_db, num_bits_per_symbol=5, coderate=3/5)
No = tf.expand_dims(No, axis=-1)

device = "/GPU:0" if tf.config.list_physical_devices('GPU') else "/CPU:0"

train = True # Change to train your own model
if train :
    # Number of iterations used for training
    NUM_TRAINING_ITERATIONS = 1 # 1000 is good value for convergence

    # Instantiating the end-to-end model for training
    # model = EndToEndSystem_bitwise_P0_fixed(N, constellation, snr_db, batch_size, device, tau)
    model = EndToEndSystem_bitwise_P0_fixed(N, constellation, device, constellation_orig, tau)

    # Adam optimizer (SGD variant)
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    # optimizer.lr.assign(0.001)

    # Training loop
    for i in range(NUM_TRAINING_ITERATIONS):

        # Forward pass
        with tf.GradientTape() as tape:
            loss, loss_ordinary, entropy_value,_,_  = model(ebno_db, No)
        # Computing and applying gradients
        weights = model.trainable_weights
        grads = tape.gradient(loss, weights)
        optimizer.apply_gradients(zip(grads, weights))
        # Print progress
        if i % 50 == 0:
          tf.print('Iteration',i,'loss', loss.numpy() / np.log(2), 'loss_ordinary', loss_ordinary.numpy() / np.log(2), 'entropy_value', entropy_value.numpy() / np.log(2))

# %%
ebno_db = tf.random.uniform(shape=[1], minval=5.0, maxval=5.2)

# ebno_db = tf.convert_to_tensor([5.0])

No = sn.phy.utils.ebnodb2no(ebno_db, num_bits_per_symbol=5, coderate=3/5)
No = tf.expand_dims(No, axis=-1)

with tf.GradientTape(persistent=False) as tape:
#     tape.watch(model.trainable_variables)  # Ensure variables are watched if needed, but no gradients will be calculated
    _,_,_,shaping_probs, norm_C_points = model(ebno_db, No)


# Define constellation points (complex numbers)
points = norm_C_points.numpy().flatten()
# points = x_mod.numpy().flatten()

# Define probabilities for each point
probabilities = shaping_probs.numpy().flatten()


    # plt.savefig('const.pdf')

# Normalize the constellation
normalized_points = normalize_constellation(points, probabilities)

# Plot the constellation
plot_constellation_wlabels(normalized_points, probabilities)
print(probabilities)
# print(model.sampling.P0.numpy())
# Out:
# [0.08604552 0.051613   0.08713939 0.04973082 0.08873946 0.04968407
#  0.08462287 0.04970521 0.05083545 0.02805078 0.04963769 0.0287371
#  0.04919415 0.02760995 0.04984234 0.02870516 0.0043762  0.01225056
#  0.00429096 0.01252864 0.00440304 0.01226913 0.00449749 0.01236538
#  0.01108834 0.00702842 0.01168049 0.00715631 0.01098411 0.00691282
#  0.01102499 0.00725004]

# %%
ebno_db = tf.random.uniform(shape=[1], minval=5.0, maxval=5.2)

# ebno_db = tf.convert_to_tensor([5.0])

No = sn.phy.utils.ebnodb2no(ebno_db, num_bits_per_symbol=5, coderate=3/5)
No = tf.expand_dims(No, axis=-1)

with tf.GradientTape(persistent=False) as tape:
#     tape.watch(model.trainable_variables)  # Ensure variables are watched if needed, but no gradients will be calculated
    _,_,_,shaping_probs, norm_C_points = model(ebno_db, No)


# Define constellation points (complex numbers)
points = norm_C_points.numpy().flatten()
# points = x_mod.numpy().flatten()

# Define probabilities for each point
probabilities = shaping_probs.numpy().flatten()


    # plt.savefig('const.pdf')

# Normalize the constellation
normalized_points = normalize_constellation(points, probabilities)

# Plot the constellation
plot_constellation_wlabels(normalized_points, probabilities)
print(probabilities)
print(model.sampling.P0.numpy())
# Out:
# [0.05024353 0.05024353 0.05024353 0.05024353 0.05024353 0.05024353
#  0.05024353 0.05024353 0.05024353 0.05024353 0.05024353 0.05024353
#  0.05024353 0.05024353 0.05024353 0.05024353 0.01225647 0.01225647
#  0.01225647 0.01225647 0.01225647 0.01225647 0.01225647 0.01225647
#  0.01225647 0.01225647 0.01225647 0.01225647 0.01225647 0.01225647
#  0.01225647 0.01225647]
# [[0.8038964]]

# %%
with tf.GradientTape(persistent=False) as tape:
#     tape.watch(model.trainable_variables)  # Ensure variables are watched if needed, but no gradients will be calculated
    _,_,_,shaping_probs = model()


# Define constellation points (complex numbers)
points = model.modulator.constellation_real.numpy()+ 1j*model.modulator.constellation_imag.numpy()

# Define probabilities for each point
probabilities = shaping_probs.numpy()


    # plt.savefig('const.pdf')

# Normalize the constellation
normalized_points = normalize_constellation(points, probabilities)

# Plot the constellation
plot_constellation_wlabels(normalized_points, probabilities)
print(probabilities)
print(model.sampling.P0.numpy())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 with tf.GradientTape(persistent=False) as tape:
#       2 #     tape.watch(model.trainable_variables)  # Ensure variables are watched if needed, but no gradients will be calculated
# ----> 3     _,_,_,shaping_probs = model()
#       6 # Define constellation points (complex numbers)
#       7 points = model.modulator.constellation_real.numpy()+ 1j*model.modulator.constellation_imag.numpy()
#
# File /projappl/project_2013933/Sionna_New/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
# ...

# %%
print(repr(points))
# Out:
# array([ 0.27940372+0.12947027j,  0.8332275 -0.02610396j,
#         0.15516436-0.26301283j,  0.71029043-0.44413698j,
#        -0.16047497+0.26489648j, -0.7038625 +0.44563776j,
#        -0.27748346-0.13394257j, -0.8379445 +0.02629344j,
#         0.43486288+0.6230619j ,  0.9342381 +0.45991704j,
#         0.01777807-0.763813j  ,  0.5185018 -0.9045519j ,
#        -0.01854236+0.7587363j , -0.5192154 +0.9048189j ,
#        -0.43791628-0.6211815j , -0.93025553-0.45988175j,
#         0.9221355 +1.4791454j ,  1.5750661 -0.13026978j,
#        -0.05803994-1.7452215j ,  1.379451  -0.76501656j,
#         0.05694056+1.7451869j , -1.3781614 +0.76728857j,
#        -0.9199851 -1.4788486j , -1.5719192 +0.13327979j,
#         0.5929736 +1.140947j  ,  1.5091645 +0.66581064j,
#        -0.13966845-1.2819171j ,  0.8883482 -1.3891242j ,
#         0.1400098 +1.2830433j , -0.88754004+1.3930871j ,
#        -0.60179037-1.1419889j , -1.5085669 -0.66640425j], dtype=complex64)

# %%
for v in model.trainable_variables:
    print(v.path, v.shape)
# Out:
# end_to_end_system_bitwise_14/sampling_mechanism_14/dense_70/kernel (1, 128)
# end_to_end_system_bitwise_14/sampling_mechanism_14/dense_70/bias (128,)
# end_to_end_system_bitwise_14/sampling_mechanism_14/dense_71/kernel (128, 64)
# end_to_end_system_bitwise_14/sampling_mechanism_14/dense_71/bias (64,)
# end_to_end_system_bitwise_14/modulator_14/constellation_real (64,)
# end_to_end_system_bitwise_14/modulator_14/constellation_imag (64,)
# end_to_end_system_bitwise_14/demodulator_bitwise_14/dense_72/kernel (3, 128)
# end_to_end_system_bitwise_14/demodulator_bitwise_14/dense_72/bias (128,)
# end_to_end_system_bitwise_14/demodulator_bitwise_14/dense_73/kernel (128, 128)
# end_to_end_system_bitwise_14/demodulator_bitwise_14/dense_73/bias (128,)
# end_to_end_system_bitwise_14/demodulator_bitwise_14/dense_74/kernel (128, 6)
# end_to_end_system_bitwise_14/demodulator_bitwise_14/dense_74/bias (6,)
